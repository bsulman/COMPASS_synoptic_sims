# %% [markdown]
# # Explore SWOT data over Chesapeake
#
# SWOT resources:
# - https://podaac.github.io/tutorials/notebooks/SearchDownload_SWOTviaCMR.html
# - https://podaac.jpl.nasa.gov/SWOT?tab=datasets-information&sections=about
# - https://search.earthdata.nasa.gov/search
#
# Using EarthAccess:
# - docs: https://earthaccess.readthedocs.io/en/stable/tutorials/getting-started/
#
# <!-- ![image.png](attachment:cdcde4e9-bcef-4e27-99a1-4e22a29bb0ac.png) -->
# <!-- ![image.png](attachment:103f3d60-42f6-4266-aedb-af18e384bb66.png) -->

# %%
import geopandas as gpd
import glob
from pathlib import Path
import pandas as pd
import os
import zipfile
import earthaccess
import xarray as xr

# %matplotlib

os.getcwd()
# Out:
# Using matplotlib backend: <object object at 0x147ced420>
# '/Users/flue473/Library/CloudStorage/OneDrive-PNNL/Documents/projects/compass_fme/elm_pflotran/scripts/COMPASS_synoptic_sims/scripts'

# %%
# Use cookiejar to avoid reusing 
# https://urs.earthdata.nasa.gov/documentation/for_users/data_access/python
earthaccess.login()
# Out:
# Enter your Earthdata Login username:  efluet
# Enter your Earthdata password:  ········

# %% [markdown]
# - Water Mask Pixel Cloud NetCDF - SWOT_L2_HR_PIXC_2.0
# - Water Mask Pixel Cloud Vector Attribute NetCDF - SWOT_L2_HR_PIXCVec_2.0
# - River Vector Shapefile - SWOT_L2_HR_RiverSP_2.0
# - Lake Vector Shapefile - SWOT_L2_HR_LakeSP_2.0
# - Raster NetCDF - SWOT_L2_HR_Raster_2.0

# %%
results = earthaccess.search_data(short_name = 'SWOT_L2_HR_Raster_2.0', #'SWOT_L2_HR_PIXCVec_2.0', 
                                  bounding_box = (-76.55, 38.81,-76.55, 38.81),
                                  temporal = ('2024-02-21 00:00:00', '2024-02-29 23:59:59')) # can also specify by time
                                  # granule_name = '*369_223L*') # here we filter by Reach files (not node), pass=013, continent code=NA
# 369_222L
# 369_223L
# 354_086L
# 354_087L

    # cloud_cover = (0,30),
    # bounding_box = (-134.7, 58.9,-133.9, 59.2),
# Out:
# Granules found: 8

# %%
quicklooks = [display(g) for g in results[0:2]]
# Out:
# Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_Raster_2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Latitude': 38.5968033100428, 'Longitude': -77.78007054724934}, {'Latitude': 38.5968033100428, 'Longitude': -76.00113343934395}, {'Latitude': 39.97894754823607, 'Longitude': -76.00113343934395}, {'Latitude': 39.97894754823607, 'Longitude': -77.78007054724934}, {'Latitude': 38.5968033100428, 'Longitude': -77.78007054724934}]}}], 'BoundingRectangles': [{'WestBoundingCoordinate': -77.78007054724934, 'SouthBoundingCoordinate': 38.5968033100428, 'EastBoundingCoordinate': -76.00113343934395, 'NorthBoundingCoordinate': 39.97894754823607}]}, 'Track': {'Cycle': 11, 'Passes': [{'Pass': 354, 'Tiles': ['084L', '085L', '086L', '087L', '084R', '085R', '086R', '087R']}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-02-27T11:59:48.437Z', 'BeginningDateTime': '2024-02-27T11:59:27.340Z'}}
# Size(MB): 19.487817764282227
# Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_Raster_2.0/SWOT_L2_HR_Raster_250m_UTM18S_N_x_x_x_011_354_043F_20240227T115927_20240227T115948_PIC0_01.nc']
# Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_Raster_2.0'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Latitude': 38.5968033100428, 'Longitude': -77.78007054724934}, {'Latitude': 38.5968033100428, 'Longitude': -76.00113343934395}, {'Latitude': 39.97894754823607, 'Longitude': -76.00113343934395}, {'Latitude': 39.97894754823607, 'Longitude': -77.78007054724934}, {'Latitude': 38.5968033100428, 'Longitude': -77.78007054724934}]}}], 'BoundingRectangles': [{'WestBoundingCoordinate': -77.78007054724934, 'SouthBoundingCoordinate': 38.5968033100428, 'EastBoundingCoordinate': -76.00113343934395, 'NorthBoundingCoordinate': 39.97894754823607}]}, 'Track': {'Cycle': 11, 'Passes': [{'Pass': 354, 'Tiles': ['084L', '085L', '086L', '087L', '084R', '085R', '086R', '087R']}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2024-02-27T11:59:48.437Z', 'BeginningDateTime': '2024-02-27T11:59:27.340Z'}}
# Size(MB): 88.54029941558838
# Data: ['https://archive.swot.podaac.earthdata.nasa.gov/podaac-swot-ops-cumulus-protected/SWOT_L2_HR_Raster_2.0/SWOT_L2_HR_Raster_100m_UTM18S_N_x_x_x_011_354_043F_20240227T115927_20240227T115948_PIC0_01.nc']

# %%
# pixc_dir = "../../../../data/swot/pixc_vec/"
rast_dir = "../../../../data/swot/rast/"
earthaccess.download(results[0:8], rast_dir)
# folder = Path("./datasets/data_downloads/SWOT_files")
# Out:
#  Getting 8 granules, approx download size: 0.42 GB
# SUBMITTING | :   0%|          | 0/8 [00:00<?, ?it/s]
# PROCESSING | :   0%|          | 0/8 [00:00<?, ?it/s]
# COLLECTING | :   0%|          | 0/8 [00:00<?, ?it/s]
# ['../../../../data/swot/rast/SWOT_L2_HR_Raster_250m_UTM18S_N_x_x_x_011_354_043F_20240227T115927_20240227T115948_PIC0_01.nc',
#  '../../../../data/swot/rast/SWOT_L2_HR_Raster_100m_UTM18S_N_x_x_x_011_354_043F_20240227T115927_20240227T115948_PIC0_01.nc',
#  '../../../../data/swot/rast/SWOT_L2_HR_Raster_250m_UTM18S_N_x_x_x_011_354_044F_20240227T115947_20240227T120008_PIC0_01.nc',
#  '../../../../data/swot/rast/SWOT_L2_HR_Raster_100m_UTM18S_N_x_x_x_011_354_044F_20240227T115947_20240227T120008_PIC0_01.nc',
#  '../../../../data/swot/rast/SWOT_L2_HR_Raster_100m_UTM18S_N_x_x_x_011_369_111F_20240228T011352_20240228T011413_PIC0_01.nc',
#  '../../../../data/swot/rast/SWOT_L2_HR_Raster_250m_UTM18S_N_x_x_x_011_369_111F_20240228T011352_20240228T011413_PIC0_01.nc',
#  '../../../../data/swot/rast/SWOT_L2_HR_Raster_250m_UTM18S_N_x_x_x_011_369_112F_20240228T011412_20240228T011433_PIC0_01.nc',
#  '../../../../data/swot/rast/SWOT_L2_HR_Raster_100m_UTM18S_N_x_x_x_011_369_112F_20240228T011412_20240228T011433_PIC0_01.nc']

# %%
import glob
file_paths = glob.glob(pixc_dir+'*')[0:1]#[1:2]
file_paths
# Out:
# ['../../../../data/swot/pixc_vec/SWOT_L2_HR_PIXC_003_369_223L_20230914T031334_20230914T031345_PGC0_01.nc']

# %%
import matplotlib.pyplot as plt

# Function to create map plot
def create_map_plot(ds_pixc):#data, lat, lon):
    fig, ax = plt.subplots(1,1, figsize=(8, 8))
    # plt.figure(figsize=(8, 6))
    ax.set_aspect('equal')
    # plt.title(date)
    ax.set_ylabel('Latitude')
    ax.set_xlabel('Longitude')

    cmap = plt.cm.get_cmap('nipy_spectral')
    
    s=ax.scatter(x=ds_pixc.longitude, y=ds_pixc.latitude, c=ds_pixc.height, 
                   s=1, edgecolor='none', cmap=cmap,# cmap=plt.cm.nipy_spectral,
                vmin=-40, vmax=-29)

    bounds=list(range(-40, -29)) #[-40, -35, -30]
    
    cbar = fig.colorbar(mappable=s, ax=ax,   cmap=cmap, label='Water height (m)', boundaries=bounds) # norm=norm,
    cbar.set_label('Water height (m) to reference ellipsoid')

    ax = plt.gca()
    ax.set_xlim([xmin, xmax])
    ax.set_ylim([ymin, ymax])
    
    fig.tight_layout()

# %%
# file_paths.sort()
# xmin, xmax, ymin, ymax = -76.6, -75.2, 38.7, 39.3
# xmin, xmax, ymin, ymax = -76.4, -76.6, 38.7, 38.8

# file_paths = '../../../../data/swot/pixc_vec/SWOT_L2_HR_PIXCVec_010_369_223L_20240207T042907_20240207T042918_PIC0_01.nc'

# Loop through netCDF files
images = []
for file_path in file_paths:
    with xr.open_dataset(file_path, group = 'pixel_cloud', engine='h5netcdf') as ds_pixc:  # 
    # with nc.Dataset(file_path, 'r') as dataset:

        ds_pixc.load()  # Load to memory
        ds_pixc
        # date = datetime.strptime(file_path.split('_')[-4],'%Y%m%dT%H%M%S').strftime('%Y-%m-%d %H:%M:%S')
        # print(ds_pixc)
        # Subset variables
#         ds_pixc = ds_pixc[['height','water_frac','cross_track','sig0','classification','classification_qual']]
        
#         # Assuming you have latitude, longitude, and data variables in your netCDF file
#         lat = ds_pixc.variables['latitude'][:]
#         lon = ds_pixc.variables['longitude'][:]
#         data = ds_pixc.variables['height'][:]

#         # Create map plot
        create_map_plot(ds_pixc)#lat, lon, data)

#         # Save plot to an image file
#         image_file = file_path.replace('.nc', '.png')
#         plt.savefig(image_file, dpi=400)
#         plt.close()

#         # Append image file to list of images
#         images.append(image_file)
# ds_pixc#.variables
# Out:
# /var/folders/mc/t1rx478j0_v5wx1183167y8r0000gn/T/ipykernel_30695/1939078716.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('nipy_spectral')

# %% [markdown]
# ### Read hydro forcing from Ben

# %%
import netCDF4 as nc

# Specify the path to your NetCDF file
# file_path = '../hydro_forcing/Annapolis_CB3_3W_elev_sal_35yrs_NAVD.nc'
file_path = '../hydro_forcing/Annapolis_schismPlus2_Peter_salinity_WT6_1_39yrs_NAVD.nc'


# Open the NetCDF file using xarray
dataset = xr.open_dataset(file_path)

dataset


# # Print the dataset summary
# print(dataset)

# # Print the dimensions
# print("\nDimensions:")
# print(dataset.dims)

# # Print the coordinates
# print("\nCoordinates:")
# print(dataset.coords)

# # Print the variables
# print("\nVariables:")
# print(dataset.data_vars)
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 328482, gridcell: 1)
# Coordinates:
#   * time           (time) timedelta64[ns] 84323 days 08:16:18.871633488 ... 9...
#   * gridcell       (gridcell) int64 0
# Data variables:
#     tide_height    (time, gridcell) float64 ...
#     tide_salinity  (time, gridcell) float64 ...

# %%
# Display content info
# ds_pixc.info

# ds_pixc = ds_pixc.where((ds_pixc.latitude > ymin) & 
#                         (ds_pixc.latitude <= ymax) & 
#                         (ds_pixc.longitude > xmin) &
#                         (ds_pixc.longitude <= xmax), drop=True)
# Filter by cross-track to remove folded pixels?
# ds_pixc = ds_pixc.where(ds_pixc.cross_track > 2000, drop=True)
# ds_pixc = ds_pixc.sel(classification=np.isin(3,4))
# ds_pixc = ds_pixc.where((ds_pixc.classification==3) | (ds_pixc.classification==4), drop=True)

# ds_pixc = ds_pixc.where((ds_pixc.classification in [3,4]).any() )
# ds_pixc = ds_pixc.where((ds_pixc.height < 20) & (ds_pixc.height > -50), drop=True)

# ds_pixc = ds_pixc.where(ds_pixc.sig0 > 10e-7, drop=True)
# # Convert sigma0 from DN to decibels
# ds_pixc['sig0_db'] = np.log10(ds_pixc.sig0)*10

# ds_pixc = ds_pixc.where((ds_pixc.sig0_db > -20) & (ds_pixc.sig0_db < 40), drop=True)
